# %% [markdown]
# # This is a heading

# %% [markdown]
# ## This is a sub heading

# %% [markdown]
# #### This is h4 heading

# %% [markdown]
# **This is a bold sentence**

# %% [markdown]
# *This is a italic sentence*

# %% [markdown]
# Things to aim in this class:
#
# 1. **Data visualization skills**: Perhaps, you would anticipate to master the essence of using one or more of the following in representation of data: graphs, charts and other forms or graphics in this course. This assist in achieving a better understanding and evaluation of the information obtained in the process.
# 2. **Data Manipulation and Transformation**: It may also entail use of raw data, cleaning, transformation, and get ready for subsequent analysis.
# 3. **Mastery of Interactive Tools**: You will also be trained on how to use libraries and widgets so as to develop impressive and interactive graphics on your data.
# 4. **Data-Driven Storytelling**: This is done to learn how to narrate with charts and concentrate on how users are guided through information and trends.
# 5. **Problem-Solving with Real Data**: This can be on real-life data for a certain problem or as a way of finding something that others maybe did not want to reveal or express.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variable assignment
variable=398
print(variable)
# Out:
# 398

# %%
#for loop
for i in ["Katkam",32,"Danny",33]:
    print(i)
# Out:
# Katkam
# 32
# Danny
# 33

# %%
# a function with a print statement
x=42
y=90
def multiply(x,y):
    print(x*y)

# %%
multiply(x,y)
# Out:
# 3780

# %%
# a function with a return statement
x=42
y=90
def multiply_returning(x,y):
    return x*y

# %%
multiply_returning(x,y)
# Out:
# 3780
